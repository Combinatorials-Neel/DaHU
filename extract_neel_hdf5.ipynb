# %% [markdown]
# ## NOTEBOOK TO EXTRACT DATA FROM A NEEL HDF5

# %%
import numpy as np
import pandas as pd
import h5py
from pathlib import Path

from modules.functions import *

from modules.functions.functions_shared import make_exports_folder
from modules.functions.functions_xrd import xrd_export_spectra_to_files
from modules.functions.functions_export import *
from modules.hdf5_compilers.hdf5compile_base import populate_all_ontology_labels

# %%
hdf5_path = Path(r"C:\Users\Pierre.LE-BERRE\Folders\Data\YFeTa\YFeTa_4\YFeTa_4_1\YFeTa_4_1.hdf5")
#hdf5_path = Path(r"C:\Users\Pierre.LE-BERRE\Folders\Data\temp.hdf5")

# %% [markdown]
# ### ALL RESULTS WILL BE EXTRACTED INTO A SINGLE CSV FILE

# %%
hdf5_export_results_to_csv(hdf5_path)

# %% [markdown]
#  ### EXPORT SPECTRA INTO XY FILES
#  ### ALL IMAGES WILL BE EXTRACTED INTO PNG FILES

# %%
# XRD
with h5py.File(hdf5_path, "r") as hdf5_file:
    hdf5_path = Path(hdf5_path)
    export_path = make_exports_folder(hdf5_path)
    for name, group in hdf5_file.items():
        try:
            if group.attrs["HT_type"] == "xrd":
                xrd_export_spectra_to_files(group, export_path, save_image=False)
            if group.attrs["HT_type"] == "moke":
                hdf5_export_moke_loops(group, export_path)
            if group.attrs["HT_type"] == "sem":
                hdf5_export_sem_images(group, export_path, format="png")
        except KeyError:
            continue


    hdf5_file.flush()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11296\1818626306.py in ?()
#       9             if group.attrs["HT_type"] == "moke":
#      10                 hdf5_export_moke_loops(group, export_path)
#      11             if group.attrs["HT_type"] == "sem":
#      12                 hdf5_export_sem_images(group, export_path, format="png")
# ---> 13         except KeyError:
#      14             continue
#      15
#      16
#
# ~\Folders\Python\DaHU\modules\functions\functions_export.py in ?(moke_group, export_path)
#      89
#      90         treatment_dict = moke_read_treatment_dict_from_hdf5(position_group)
#      91
#      92         df = moke_get_measurement_from_hdf5(moke_group, target_x=x_pos, target_y=y_pos, index=0)
# ---> 93         df = moke_treat_measurement_dataframe(df, treatment_dict)
#      94
#      95         field_array = df["field"].values
#      96         magnetization_array = df["magnetization"].values
#
# ~\Folders\Python\DaHU\modules\functions\functions_moke.py in ?(measurement_df, options_dict)
#     158     max_field = pulse_voltage * coil_factor / 100
#     159
#     160     measurement_df.loc[:midpoint, "field"] = measurement_df.loc[
#     161         :midpoint, "integrated_pulse"
# --> 162     ].apply(lambda x: -x * max_field / np.abs(measurement_df["integrated_pulse"].min()))
#     163     measurement_df.loc[midpoint:, "field"] = measurement_df.loc[
#     164         midpoint:, "integrated_pulse"
#     165     ].apply(lambda x: -x * max_field / np.abs(measurement_df["integrated_pulse"].max()))
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\series.py in ?(self, func, convert_dtype, args, by_row, **kwargs)
#    4920             convert_dtype=convert_dtype,
#    4921             by_row=by_row,
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\apply.py in ?(self)
#    1423         if self.by_row == "_compat":
#    1424             return self.apply_compat()
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\apply.py in ?(self)
#    1503         # we need to give `na_action="ignore"` for categorical data.
#    1504         # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#    1510
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\base.py in ?(self, mapper, na_action, convert)
#     917
#     918         if isinstance(arr, ExtensionArray):
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\algorithms.py in ?(arr, mapper, na_action, convert)
#    1739
#    1740     # we must convert to python types
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#    1746             values, mapper, mask=isna(values).view(np.uint8), convert=convert
#
# lib.pyx in ?()
# -> 2972 'Could not get source, probably due dynamically evaluated source code.'
#
# ~\Folders\Python\DaHU\modules\functions\functions_moke.py in ?(x)
# --> 162     ].apply(lambda x: -x * max_field / np.abs(measurement_df["integrated_pulse"].min()))
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4074                 self.columns.is_unique
#    4075                 and key in self.columns
#    4076                 or key in self.columns.drop_duplicates(keep=False)
#    4077             ):
# -> 4078                 return self._get_item_cache(key)
#    4079
#    4080             elif is_mi and self.columns.is_unique and key in self.columns:
#    4081                 return self._getitem_multilevel(key)
#
# ~\Folders\Python\DaHU\venv\Lib\site-packages\pandas\core\frame.py in ?(self, item)
# -> 4626     def _get_item_cache(self, item: Hashable) -> Series:
#    4627         """Return the cached item, item represents a label indexer."""
#    4628         if using_copy_on_write() or warn_copy_on_write():
#    4629             loc = self.columns.get_loc(item)
#
# KeyboardInterrupt:
